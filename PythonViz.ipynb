# %% [markdown]
# <a href="https://colab.research.google.com/github/jegrossman2004/DataVis/blob/main/PythonViz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib==3.4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.1/37.1 MB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
from matplotlib import pyplot as plt
plt.style.use('seaborn-whitegrid')

import numpy as np
import requests
import pandas as pd
# Out:
# <ipython-input-20-87d4538d1d36>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
df = pd .read_csv("/content/sample_data/Top_Highest_Openings.csv")

# %%
print(df)
# Out:
#                                         Release    Opening  Total Gross  \
# 0                             Avengers: Endgame  357115007    858373000
# 1                       Spider-Man: No Way Home  260138569    804793477
# 2                        Avengers: Infinity War  257698183    678815482
# 3    Star Wars: Episode VII - The Force Awakens  247966675    936662225
# 4       Star Wars: Episode VIII - The Last Jedi  220009584    620181382
# ..                                          ...        ...          ...
# 995                      The Hitman's Bodyguard   21384504     75468583
# 996                            Angel Has Fallen   21380987     69030436
# 997                   Ice Age: Collision Course   21373064     64063008
# 998                      Why Did I Get Married?   21353789     55204525
# 999                                       Turbo   21312625     83028128
#
#      % of Total  Theaters  Average        Date  \
# 0          41.6      4662    76601  26-04-2019
# ...

# %%
values = list(df.groupby('Distributor')['Total Gross'].mean())
labels = list(set(list(df['Distributor'])))

# %%
fig=plt.figure()
ax=plt.axes()
plt.xticks(rotation=90)
ax.bar(labels,values,color='green')
ax.set_ylabel("Total Gross in Hundreds of Millions of Dollars")
ax.set_xlabel("Distributor")
ax.set_title('Mean Total Gross by Distributor')
# Out:
# Text(0.5, 1.0, 'Mean Total Gross by Distributor')

# %%
plt.style.use('ggplot')
x=list(df['Theaters'])
y=list(df['Average'])
fig,ax=plt.subplots()
ax.scatter(x,y,s=80,marker=(5,0),color='red')
ax.set_ylabel("Average Revenue for each Theater where Movie Played")
ax.set_xlabel("Number of Theaters where Movie Played")
ax.set_title('Theater Revenue')
# Out:
# Text(0.5, 1.0, 'Theater Revenue')

# %%
plt.style.use('dark_background')
fig,ax=plt.subplots()
ax.boxplot(list(df['% of Total']),1)
ax.set_ylabel("% Of Total Revenue in a Movie's Opening Weekend")
ax.set_title("Opening Weekend Revenue")
# Out:
# Text(0.5, 1.0, 'Opening Weekend Revenue')
